# %% [markdown]
# # Instalacion e Importacion de Herramientas

# %%
#Instalacion de libreria necesaria para la letura dr arhivos .xlsx
# !pip install openpyxl
# !pip install seaborn
! python.exe -m pip install --upgrade pip
# !pip install jupyterthemes
# Out:
# Requirement already satisfied: openpyxl in c:\users\mateo\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\mateo\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: seaborn in c:\users\mateo\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\mateo\anaconda3\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\mateo\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\mateo\anaconda3\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\mateo\anaconda3\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mateo\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\mateo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pip in c:\users\mateo\anaconda3\lib\site-packages (23.0.1)
# Collecting jupyterthemes
#   Downloading jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core in c:\users\mateo\anaconda3\lib\site-packages (from jupyterthemes) (4.9.2)
# Requirement already satisfied: notebook>=5.6.0 in c:\users\mateo\anaconda3\lib\site-packages (from jupyterthemes) (6.4.8)
# Collecting lesscpy>=0.11.2
#   Downloading lesscpy-0.15.1-py2.py3-none-any.whl (46 kB)
#      -------------------------------------- 46.7/46.7 kB 775.8 kB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.4.1 in c:\users\mateo\anaconda3\lib\site-packages (from jupyterthemes) (8.2.0)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\mateo\anaconda3\lib\site-packages (from jupyterthemes) (3.5.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (66.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: backcall in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.11.2)
# Requirement already satisfied: colorama in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.4)
# Requirement already satisfied: decorator in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mateo\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.1)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ---------------------------------------- 49.6/49.6 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mateo\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.3.2)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.1.12)
# Requirement already satisfied: ipykernel in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.9.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.13.1)
# Requirement already satisfied: nbformat in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.3.0)
# Requirement already satisfied: prometheus-client in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.4.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (22.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (2.11.3)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.1)
# Requirement already satisfied: ipython-genutils in c:\users\mateo\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mateo\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (302)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mateo\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\mateo\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\mateo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\mateo\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mateo\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mateo\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mateo\anaconda3\lib\site-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.13)
# Requirement already satisfied: testpath in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: bleach in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\mateo\anaconda3\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mateo\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\mateo\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.15.1)
# Requirement already satisfied: executing in c:\users\mateo\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\mateo\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\mateo\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.0.5)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mateo\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mateo\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mateo\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mateo\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=5.6.0->jupyterthemes) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\mateo\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\mateo\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Installing collected packages: ply, lesscpy, jupyterthemes
# Successfully installed jupyterthemes-0.20.0 lesscpy-0.15.1 ply-3.11

# %%
#Importación de librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from jupyterthemes import jtplot

# %%
df = pd.read_excel('colombia.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49359 entries, 0 to 49358
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Ano                 49359 non-null  object
#  1   Fecha               49359 non-null  object
#  2   Departamento        49359 non-null  object
#  3   Municipio           49359 non-null  object
#  4   Día                 49359 non-null  object
#  5   Hora                49358 non-null  object
#  6   Barrio              49359 non-null  object
#  7   Zona                49359 non-null  object
#  8   Clase de sitio      49358 non-null  object
#  9   Arma empleada       49358 non-null  object
#  10  Móvil Agresor       49358 non-null  object
#  11  Móvil Victima       49358 non-null  object
#  12  Edad                49359 non-null  object
#  13  Sexo                49359 non-null  object
#  14  Estado civil        49358 non-null  object
#  15  País de nacimiento  49359 non-null  object
#  16  Clase de empleado   49358 non-null  object
#  17  Profesión           49359 non-null  object
#  18  Escolaridad         49359 non-null  object
#  19  Código DANE         49359 non-null  object
#  20  Cantidad            49359 non-null  object
# dtypes: object(21)
# memory usage: 7.9+ MB

# %% [markdown]
# # Limpieza de Datos

# %%
#borramos todas las filas las cuales no tengan ninguna informacion
df=df.dropna()
df = df.drop_duplicates()

# %%
new=df.drop(columns=['Fecha','Municipio','Barrio','Móvil Victima',
                      'Código DANE','Código DANE','Profesión',
                      'Clase de empleado', 'Hora','Móvil Agresor','Estado civil','Escolaridad','Cantidad'])
new.info(14)
new.head(14)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49358 entries, 1 to 49358
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Ano                 49358 non-null  object
#  1   Departamento        49358 non-null  object
#  2   Día                 49358 non-null  object
#  3   Zona                49358 non-null  object
#  4   Clase de sitio      49358 non-null  object
#  5   Arma empleada       49358 non-null  object
#  6   Edad                49358 non-null  object
#  7   Sexo                49358 non-null  object
#  8   País de nacimiento  49358 non-null  object
# dtypes: object(9)
# memory usage: 3.8+ MB
#        Ano Departamento     Día    Zona                      Clase de sitio  \
# 1   2019.0    ANTIOQUIA  Martes   RURAL                  FINCAS Y SIMILARES
# 2   2019.0    ANTIOQUIA  Martes  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 3   2019.0    ANTIOQUIA  Martes  URBANA                 CASAS DE HABITACION
# 4   2019.0    ANTIOQUIA  Martes  URBANA                       VIAS PUBLICAS
# 5   2019.0    ANTIOQUIA  Martes  URBANA                       VIAS PUBLICAS
# 6   2019.0    ANTIOQUIA  Martes  URBANA                 CASAS DE HABITACION
# 7   2019.0    ANTIOQUIA  Martes  URBANA                       VIAS PUBLICAS
# 8   2019.0    ANTIOQUIA  Martes  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 9   2019.0    ANTIOQUIA  Martes  URBANA                       VIAS PUBLICAS
# 10  2019.0    ANTIOQUIA  Martes  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 11  2019.0    ANTIOQUIA  Martes  URBANA                          DISCOTECAS
# 12  2019.0    ANTIOQUIA  Martes  URBANA                       VIAS PUBLICAS
# 13  2019.0    ANTIOQUIA  Martes  URBANA                       VIAS PUBLICAS
# 14  2019.0    ANTIOQUIA  Martes  URBANA                       VIAS PUBLICAS
#
#                   Arma empleada Edad       Sexo País de nacimiento
# 1   ARMA BLANCA / CORTOPUNZANTE   37  MASCULINO           COLOMBIA
# 2                 ARMA DE FUEGO   24  MASCULINO           COLOMBIA
# 3   ARMA BLANCA / CORTOPUNZANTE   62   FEMENINO           COLOMBIA
# 4   ARMA BLANCA / CORTOPUNZANTE   34  MASCULINO           COLOMBIA
# 5   ARMA BLANCA / CORTOPUNZANTE   33  MASCULINO           COLOMBIA
# 6   ARMA BLANCA / CORTOPUNZANTE   37  MASCULINO           COLOMBIA
# 7   ARMA BLANCA / CORTOPUNZANTE   37  MASCULINO           COLOMBIA
# 8   ARMA BLANCA / CORTOPUNZANTE   22  MASCULINO           COLOMBIA
# 9   ARMA BLANCA / CORTOPUNZANTE   20  MASCULINO           COLOMBIA
# 10  ARMA BLANCA / CORTOPUNZANTE   37  MASCULINO           COLOMBIA
# 11                ARMA DE FUEGO   30  MASCULINO           COLOMBIA
# 12                ARMA DE FUEGO   18  MASCULINO           COLOMBIA
# 13  ARMA BLANCA / CORTOPUNZANTE   30  MASCULINO           COLOMBIA
# 14  ARMA BLANCA / CORTOPUNZANTE   20  MASCULINO           COLOMBIA

# %% [markdown]
# # Actualizacion y Creacion de la BD

# %%
#guardamos en un archivo xlsx nuevo los datos limpios
new.to_excel('archivo_limpiado-Colombia.xlsx')
new
# Out:
#           Ano Departamento     Día    Zona  \
# 1      2019.0    ANTIOQUIA  Martes   RURAL
# 2      2019.0    ANTIOQUIA  Martes  URBANA
# 3      2019.0    ANTIOQUIA  Martes  URBANA
# 4      2019.0    ANTIOQUIA  Martes  URBANA
# 5      2019.0    ANTIOQUIA  Martes  URBANA
# ...       ...          ...     ...     ...
# 49354  2016.0        VALLE  Sábado   RURAL
# 49355  2016.0        VALLE  Sábado  URBANA
# 49356  2016.0        VALLE  Sábado   RURAL
# 49357  2016.0        VALLE  Sábado  URBANA
# 49358  2016.0        VALLE  Sábado   RURAL
#
#                            Clase de sitio                Arma empleada Edad  \
# 1                      FINCAS Y SIMILARES  ARMA BLANCA / CORTOPUNZANTE   37
# 2      FRENTE A RESIDENCIAS - VIA PUBLICA                ARMA DE FUEGO   24
# 3                     CASAS DE HABITACION  ARMA BLANCA / CORTOPUNZANTE   62
# 4                           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE   34
# 5                           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE   33
# ...                                   ...                          ...  ...
# 49354                  FINCAS Y SIMILARES                ARMA DE FUEGO   32
# 49355               DENTRO DE LA VIVIENDA                ARMA DE FUEGO   67
# 49356                       VIAS PUBLICAS                ARMA DE FUEGO   23
# 49357                       VIAS PUBLICAS                ARMA DE FUEGO   22
# 49358                       VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE   59
#
#             Sexo País de nacimiento
# 1      MASCULINO           COLOMBIA
# 2      MASCULINO           COLOMBIA
# 3       FEMENINO           COLOMBIA
# 4      MASCULINO           COLOMBIA
# 5      MASCULINO           COLOMBIA
# ...          ...                ...
# 49354  MASCULINO           COLOMBIA
# 49355  MASCULINO           COLOMBIA
# 49356  MASCULINO           COLOMBIA
# 49357  MASCULINO           COLOMBIA
# 49358  MASCULINO           COLOMBIA
#
# [49358 rows x 9 columns]

# %%
import csv
import couchdb
#nos conectamos a la bd de couch con nuestras credenciales
couch = couchdb.Server('http://root:mateo@localhost:5984/')
db = couch.create('xlsx') #Creamos el nombre de nuestra BD
# Out:
# ---------------------------------------------------------------------------
# PreconditionFailed                        Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       3 #nos conectamos a la bd de couch con nuestras credenciales
#       4 couch = couchdb.Server('http://root:mateo@localhost:5984/')
# ----> 5 db = couch.create('xlsx')
#
# File ~\anaconda3\lib\site-packages\couchdb\client.py:221, in Server.create(self, name)
#     213 def create(self, name):
#     214     """Create a new database with the given name.
#     215
#     216     :param name: the name of the database
#    (...)
#     219     :raise PreconditionFailed: if a database with that name already exists
#     220     """
# --> 221     self.resource.put_json(name)
#     222     return self[name]
#
# File ~\anaconda3\lib\site-packages\couchdb\http.py:577, in Resource.put_json(self, path, body, headers, **params)
#     576 def put_json(self, path=None, body=None, headers=None, **params):
# --> 577     return self._request_json('PUT', path, body=body, headers=headers,
#     578                               **params)
#
# File ~\anaconda3\lib\site-packages\couchdb\http.py:595, in Resource._request_json(self, method, path, body, headers, **params)
#     594 def _request_json(self, method, path=None, body=None, headers=None, **params):
# --> 595     status, headers, data = self._request(method, path, body=body,
#     596                                           headers=headers, **params)
#     597     if 'application/json' in headers.get('content-type', ''):
#     598         data = json.decode(data.read().decode('utf-8'))
#
# File ~\anaconda3\lib\site-packages\couchdb\http.py:590, in Resource._request(self, method, path, body, headers, **params)
#     588 else:
#     589     url = urljoin(self.url, **params)
# --> 590 return self.session.request(method, url, body=body,
#     591                             headers=all_headers,
#     592                             credentials=self.credentials)
#
# File ~\anaconda3\lib\site-packages\couchdb\http.py:427, in Session.request(self, method, url, body, headers, credentials, num_redirects)
#     425     raise ResourceConflict(error)
#     426 elif status == 412:
# --> 427     raise PreconditionFailed(error)
#     428 else:
#     429     raise ServerError((status, error))
#
# PreconditionFailed: ('file_exists', 'The database could not be created, the file already exists.')

# %%
#leemos y elistamos el archivo xlsx
data = pd.read_excel('archivo_limpiado-Colombia.xlsx')
data_list = data.values.tolist()
data
# Out:
#        Unnamed: 0   Ano Departamento     Día    Zona  \
# 0               1  2019    ANTIOQUIA  Martes   RURAL
# 1               2  2019    ANTIOQUIA  Martes  URBANA
# 2               3  2019    ANTIOQUIA  Martes  URBANA
# 3               4  2019    ANTIOQUIA  Martes  URBANA
# 4               5  2019    ANTIOQUIA  Martes  URBANA
# ...           ...   ...          ...     ...     ...
# 49353       49354  2016        VALLE  Sábado   RURAL
# 49354       49355  2016        VALLE  Sábado  URBANA
# 49355       49356  2016        VALLE  Sábado   RURAL
# 49356       49357  2016        VALLE  Sábado  URBANA
# 49357       49358  2016        VALLE  Sábado   RURAL
#
#                            Clase de sitio                Arma empleada Edad  \
# 0                      FINCAS Y SIMILARES  ARMA BLANCA / CORTOPUNZANTE   37
# 1      FRENTE A RESIDENCIAS - VIA PUBLICA                ARMA DE FUEGO   24
# 2                     CASAS DE HABITACION  ARMA BLANCA / CORTOPUNZANTE   62
# 3                           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE   34
# 4                           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE   33
# ...                                   ...                          ...  ...
# 49353                  FINCAS Y SIMILARES                ARMA DE FUEGO   32
# 49354               DENTRO DE LA VIVIENDA                ARMA DE FUEGO   67
# 49355                       VIAS PUBLICAS                ARMA DE FUEGO   23
# 49356                       VIAS PUBLICAS                ARMA DE FUEGO   22
# 49357                       VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE   59
#
#             Sexo País de nacimiento
# 0      MASCULINO           COLOMBIA
# 1      MASCULINO           COLOMBIA
# 2       FEMENINO           COLOMBIA
# 3      MASCULINO           COLOMBIA
# 4      MASCULINO           COLOMBIA
# ...          ...                ...
# 49353  MASCULINO           COLOMBIA
# 49354  MASCULINO           COLOMBIA
# 49355  MASCULINO           COLOMBIA
# 49356  MASCULINO           COLOMBIA
# 49357  MASCULINO           COLOMBIA
#
# [49358 rows x 10 columns]

# %%
#en este apartado debimos covertir los archivos a json, ya que el archivo xlsx
#ya que tiene valores flotantes que el los datos de couchdb no permite ya que estan fuera de rango
#para el archivo json que se crea en couchdb

import json
#tenemos que convertir los datos a json para que podamos guardar valores flotantes 
#que puedan ser guardados en couch
data = pd.read_excel('archivo_limpiado-Colombia.xlsx')
# Convertir los datos a formato JSON
json_data = data.to_json(orient='records')

parsed_data = json.loads(json_data)
for row in parsed_data:
    for key, value in row.items():
        if isinstance(value, float):
            if abs(value) > 1.7976931348623157E+308:
                # Hacer algo para corregir el valor, como establecerlo en el valor máximo permitido en JSON
                row[key] = 1.7976931348623157E+308

# %%
#guradamos el formato a la bd            
for row in parsed_data:
    db.save(row)

# %% [markdown]
# # Graficas

# %%
"Grafica 1"
"Por edad"
editorcol = data.drop(columns = ['Departamento','Clase de sitio','Arma empleada',
                               'País de nacimiento','Día','Zona'])
grafica1 = editorcol.sort_values('Edad',ascending=False).head(50)
grafica1 = grafica1.set_index('Edad')
grafica1
# Out:
#       Unnamed: 0   Ano       Sexo
# Edad
# 98          7067  2019  MASCULINO
# 94         44530  2016  MASCULINO
# 93         23619  2018  MASCULINO
# 93         29098  2017   FEMENINO
# 92         14235  2018  MASCULINO
# 91         44304  2016  MASCULINO
# 91         14327  2018  MASCULINO
# 91         25449  2017  MASCULINO
# 91         26311  2017  MASCULINO
# 90         11186  2019  MASCULINO
# 90          8983  2019  MASCULINO
# 90         22595  2018   FEMENINO
# 90         39202  2016  MASCULINO
# 9          36852  2017   FEMENINO
# 9          44717  2016  MASCULINO
# 9           6574  2019  MASCULINO
# 9          42978  2016  MASCULINO
# 9            535  2019  MASCULINO
# 9          40475  2016  MASCULINO
# 9          49038  2016  MASCULINO
# 9          21827  2018   FEMENINO
# 9          31422  2017  MASCULINO
# 9          37536  2016  MASCULINO
# 9           4076  2019  MASCULINO
# 9           7758  2019  MASCULINO
# 9          11178  2019  MASCULINO
# 9          10861  2019   FEMENINO
# 9          39158  2016   FEMENINO
# 9          11682  2019  MASCULINO
# 9          40162  2016   FEMENINO
# 9          23393  2018   FEMENINO
# 9          23616  2018  MASCULINO
# 9           4861  2019   FEMENINO
# 9          28795  2017  MASCULINO
# 9          27567  2017  MASCULINO
# 9          47730  2016   FEMENINO
# 9           5923  2019  MASCULINO
# 9          46957  2016   FEMENINO
# 9          13854  2018   FEMENINO
# 89          8605  2019   FEMENINO
# 89         20094  2018  MASCULINO
# 88         21580  2018  MASCULINO
# 88         43426  2016  MASCULINO
# 88         23189  2018   FEMENINO
# 88         16852  2018  MASCULINO
# 88         33321  2017   FEMENINO
# 88         38744  2016  MASCULINO
# 88         15020  2018   FEMENINO
# 87         22443  2018  MASCULINO
# 87         14090  2018  MASCULINO

# %%
plt.figure(figsize=(12,6))
plt.title("Edades afectadas por año")
color = sns.color_palette("Set2")
sns.set_palette(color)
sns.lineplot(data=grafica1.reset_index(), x='Ano', y=grafica1.index, hue='Sexo')
# Out:
# <AxesSubplot:title={'center':'Edades afectadas por año'}, xlabel='Ano', ylabel='Edad'>

# %%
"GRAFICA 2"
"Por arma empleada"
jtplot.style()
plt.title("Armas empleadas en homicidios por año")
color = sns.color_palette("Set2")
sns.set_palette(color)
sns.stripplot(data=data, x='Ano', y='Arma empleada', hue='Sexo', dodge=True)
plt.show()

# %%
"Grafica 3"
"Por país de nacimiento"
editorcol = data.drop(columns = ['Departamento','Clase de sitio','Arma empleada','Zona','Edad','Día'])
grafica3 = editorcol.sort_values('País de nacimiento',ascending=False)
grafica3 = grafica3.set_index('País de nacimiento')
grafica3
# Out:
#                     Unnamed: 0   Ano       Sexo
# País de nacimiento
# VENEZUELA                24912  2018   FEMENINO
# VENEZUELA                 7852  2019  MASCULINO
# VENEZUELA                 1629  2019  MASCULINO
# VENEZUELA                23340  2018  MASCULINO
# VENEZUELA                19918  2018  MASCULINO
# ...                        ...   ...        ...
# -                         7168  2019  MASCULINO
# -                        24502  2018  MASCULINO
# -                        42691  2016  MASCULINO
# -                        11219  2019   FEMENINO
# -                        26520  2017  MASCULINO
#
# [49358 rows x 3 columns]

# %%
plt.figure(figsize=(15,30))
plt.title("Nacionalidades afectadas por año")
color = sns.color_palette("Set2")
sns.set_palette(color)
sns.violinplot(data=grafica3, x=grafica3['Ano'], y=grafica3.index)
# Out:
# <AxesSubplot:title={'center':'Nacionalidades afectadas por año'}, xlabel='Ano', ylabel='País de nacimiento'>
