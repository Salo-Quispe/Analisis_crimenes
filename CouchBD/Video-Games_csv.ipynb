# %% [markdown]
# # ***OBTENCION DE DATOS***

# %%
#Instalacion de librerias para la extarancion de datos

# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
#Importacion de librerias para la extarancion de datos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#extraccion de los datos
xml=pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')
xml.info()
xml
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %% [markdown]
# # ***LIMPIEZA DE DATOS***

# %%
xml = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')
xml = xml.drop(columns=['Critic_Score', 'Critic_Count','User_Score', 'User_Count','Developer','Rating'])
xml = xml.rename(columns={'Name':'Nombre',
                             'Platform':'Plataforma',
                             'Year_of_Release':'Año',
                             'Genre':'Genero',
                             'Publisher':'Editor',
                             'NA_Sales':'Ventas_NA',
                             'EU_Sales':'Ventas_EU',
                             'JP_Sales':'Ventas_JP',
                             'Other_Sales':'Otras_Ventas',
                             'Global_Sales':'Ventas_Globales'})
xml
# Out:
#                               Nombre Plataforma     Año        Genero  \
# 0                         Wii Sports        Wii  2006.0        Sports
# 1                  Super Mario Bros.        NES  1985.0      Platform
# 2                     Mario Kart Wii        Wii  2008.0        Racing
# 3                  Wii Sports Resort        Wii  2009.0        Sports
# 4           Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# ...                              ...        ...     ...           ...
# 16714  Samurai Warriors: Sanada Maru        PS3  2016.0        Action
# 16715               LMA Manager 2007       X360  2006.0        Sports
# 16716        Haitaka no Psychedelica        PSV  2016.0     Adventure
# 16717               Spirits & Spells        GBA  2003.0      Platform
# 16718            Winning Post 8 2016        PSV  2016.0    Simulation
#
#              Editor  Ventas_NA  Ventas_EU  Ventas_JP  Otras_Ventas  \
# ...

# %%
#Guradamos los datos limpios en otro archivo .csv 
xml.to_csv('archivo_limpiado-VideoGames.csv', index=False)
xml
# Out:
#                               Nombre Plataforma     Año        Genero  \
# 0                         Wii Sports        Wii  2006.0        Sports
# 1                  Super Mario Bros.        NES  1985.0      Platform
# 2                     Mario Kart Wii        Wii  2008.0        Racing
# 3                  Wii Sports Resort        Wii  2009.0        Sports
# 4           Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# ...                              ...        ...     ...           ...
# 16714  Samurai Warriors: Sanada Maru        PS3  2016.0        Action
# 16715               LMA Manager 2007       X360  2006.0        Sports
# 16716        Haitaka no Psychedelica        PSV  2016.0     Adventure
# 16717               Spirits & Spells        GBA  2003.0      Platform
# 16718            Winning Post 8 2016        PSV  2016.0    Simulation
#
#              Editor  Ventas_NA  Ventas_EU  Ventas_JP  Otras_Ventas  \
# ...

# %% [markdown]
# # Guardamos los Datos Limpios a la Base de Datos

# %%
import csv
import couchdb

# %%
#leemos el archivo limpio
data = pd.read_csv('archivo_limpiado-VideoGames.csv')

# %%
#enlistamos los datos del archivo csv
data_list = data.values.tolist()

# %%
#nos conectamos a la bd de couch con nuestras credenciales
couch = couchdb.Server('http://root:mateo@localhost:5984/')
db = couch.create('videogames')

# %%
#en este apartado debimos covertir los archivos a jso, ya que el archivo csv
#ya que tiene valores flotantes que el los datos de couchdb no permite ya que estan fuera de rango
#para el archivo json que se crea en couchdb

import json
#tenemos que convertir los datos a json para que podamos guardar valores flotantes 
#que puedan ser guardados en couch
data = pd.read_csv('archivo_limpiado-VideoGames.csv')
# Convertir los datos a formato JSON
json_data = data.to_json(orient='records')

parsed_data = json.loads(json_data)
for row in parsed_data:
    for key, value in row.items():
        if isinstance(value, float):
            if abs(value) > 1.7976931348623157E+308:
                # Hacer algo para corregir el valor, como establecerlo en el valor máximo permitido en JSON
                row[key] = 1.7976931348623157E+308

# %%
#guradamos el formato a la bd            
for row in parsed_data:
    db.save(row)

# %% [markdown]
# # ***GRAFICAS***

# %%
"Grafica 1"
"En base al Editor"

editorcol = xml.drop(columns = ['Año', 'Genero', 'Nombre','Plataforma'])

editorsum = editorcol.groupby('Editor').sum()
editorsum = editorsum.sort_values(by=['Ventas_Globales'], ascending=False).head(10)
editorsum = editorsum.rename(index={'Electronic Arts':'EA',
                                    'Sony Computer Entertainment': 'Sony',
                                    'Take-Two Interactive': 'Take-Two',
                                    'Konami Digital Entertainment':'Konami',
                                    'Namco Bandai Games':'Namco'})
editorsum
# Out:
#             Ventas_NA  Ventas_EU  Ventas_JP  Otras_Ventas  Ventas_Globales
# Editor
# Nintendo       816.97     419.01     458.15         94.68          1788.81
# EA             599.50     373.91      14.35        128.96          1116.96
# Activision     432.59     215.90       6.71         75.81           731.16
# Sony           266.17     186.56      74.15         79.67           606.48
# Ubisoft        252.74     161.99       7.52         49.18           471.61
# Take-Two       222.94     119.25       5.93         55.72           403.82
# THQ            207.72      93.78       5.01         31.89           338.44
# Konami          91.90      68.98      91.40         29.93           282.39
# Sega           108.61      80.66      57.06         23.81           270.35
# Namco           69.90      42.16     127.85         14.60           254.62

# %%
from jupyterthemes import jtplot
jtplot.style()
plt.figure(figsize=(15,8))
plt.title("Ventas por Editor")

sns.barplot(x=editorsum.index, y=editorsum['Ventas_Globales'])
# Out:
# <AxesSubplot:title={'center':'Ventas por Editor'}, xlabel='Editor', ylabel='Ventas_Globales'>

# %%
"Grafica 2"
"En base al genero"

genero = xml.drop(columns = ['Año','Nombre','Plataforma','Editor'])
genero
# Out:
#              Genero  Ventas_NA  Ventas_EU  Ventas_JP  Otras_Ventas  \
# 0            Sports      41.36      28.96       3.77          8.45
# 1          Platform      29.08       3.58       6.81          0.77
# 2            Racing      15.68      12.76       3.79          3.29
# 3            Sports      15.61      10.93       3.28          2.95
# 4      Role-Playing      11.27       8.89      10.22          1.00
# ...             ...        ...        ...        ...           ...
# 16714        Action       0.00       0.00       0.01          0.00
# 16715        Sports       0.00       0.01       0.00          0.00
# 16716     Adventure       0.00       0.00       0.01          0.00
# 16717      Platform       0.01       0.00       0.00          0.00
# 16718    Simulation       0.00       0.00       0.01          0.00
#
#        Ventas_Globales
# 0                82.53
# 1                40.24
# 2                35.52
# 3                32.77
# 4                31.37
# ...

# %%
generocounts = genero.groupby('Genero').count()
generocounts = generocounts.rename(index={'Role-Playing':'Roleplay'})
generocounts = generocounts.sort_values('Ventas_Globales', ascending=False)
generocounts
# Out:
#             Ventas_NA  Ventas_EU  Ventas_JP  Otras_Ventas  Ventas_Globales
# Genero
# Action           3370       3370       3370          3370             3370
# Sports           2348       2348       2348          2348             2348
# Misc             1750       1750       1750          1750             1750
# Roleplay         1500       1500       1500          1500             1500
# Shooter          1323       1323       1323          1323             1323
# Adventure        1303       1303       1303          1303             1303
# Racing           1249       1249       1249          1249             1249
# Platform          888        888        888           888              888
# Simulation        874        874        874           874              874
# Fighting          849        849        849           849              849
# Strategy          683        683        683           683              683
# ...

# %%
jtplot.style()
plt.figure(figsize=(10,6))
plt.title("Ventas por género")

sns.barplot(x=generocounts['Ventas_Globales'], y=generocounts.index)
# Out:
# <AxesSubplot:title={'center':'Ventas por género'}, xlabel='Ventas_Globales', ylabel='Genero'>

# %%
"Grafica 3"
"En base a la plataforma"

plataforma = xml.drop(columns = ['Genero', 'Nombre','Año','Editor','Ventas_NA','Ventas_EU', 'Ventas_JP','Ventas_NA', 'Otras_Ventas'])

plataforma = plataforma.groupby('Plataforma').count()
plataforma = plataforma.sort_values('Ventas_Globales', ascending=False)
plataforma = plataforma.head(10)

plataforma
# Out:
#             Ventas_Globales
# Plataforma
# PS2                    2161
# DS                     2152
# PS3                    1331
# Wii                    1320
# X360                   1262
# PSP                    1209
# PS                     1197
# PC                      974
# XB                      824
# GBA                     822

# %%
jtplot.style()
plt.figure(figsize=(12,6))
plt.title("Ventas por Plataforma")

color = sns.color_palette("hls", 8)

sns.set_palette(color)

sns.barplot(x=plataforma.index, y=plataforma['Ventas_Globales'])
# Out:
# <AxesSubplot:title={'center':'Ventas por Plataforma'}, xlabel='Plataforma', ylabel='Ventas_Globales'>
