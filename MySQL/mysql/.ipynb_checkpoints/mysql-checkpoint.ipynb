# %% [markdown]
# # Instalacion e Importacion de Herramientas

# %%
# !pip install mysql-connector-python
# !pip install mysqlclient
# Out:
# ...
#      ------------------------------------ 178.5/178.5 kB 598.9 kB/s eta 0:00:00
# ...

# %%
import MySQLdb

import pandas as pd

# lee el archivo JSON
df = pd.read_json('VIAJES_MARITIMOS_DIPUTADOS_ISLAS_CANARIAS.json')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   anio                123 non-null    int64
#  1   tipo                123 non-null    object
#  2   coste               123 non-null    float64
#  3   diputado_apellido1  123 non-null    object
#  4   diputado_apellido2  123 non-null    object
#  5   diputado_nombre     123 non-null    object
#  6   id_diputado         123 non-null    int64
#  7   mes                 123 non-null    object
#  8   tipo_viaje          123 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 8.8+ KB
#      anio tipo   coste diputado_apellido1 diputado_apellido2 diputado_nombre  \
# 0    2022   TM   45.38             Alemán              Ojeda           Nayra
# 1    2022   TM  475.00             Alemán              Ojeda           Nayra
# ...

# %% [markdown]
# # Limpieza de datos

# %%
#borramos todas las filas las cuales no tengan ninguna informacion
df=df.dropna()
df = df.drop_duplicates()
df
# Out:
#      anio tipo   coste diputado_apellido1 diputado_apellido2 diputado_nombre  \
# 0    2022   TM   45.38             Alemán              Ojeda           Nayra
# 1    2022   TM  475.00             Alemán              Ojeda           Nayra
# 2    2022   TM  427.50             Alemán              Ojeda           Nayra
# 3    2022   TM   71.25             Alemán              Ojeda           Nayra
# 4    2022   TM  118.75             Alemán              Ojeda           Nayra
# ..    ...  ...     ...                ...                ...             ...
# 118  2022   TM   10.83             Suárez               Nuez            Poli
# 119  2022   TM  201.39             Suárez               Nuez            Poli
# 120  2022   TM  188.10             Suárez               Nuez            Poli
# 121  2022   TM  107.14             Suárez               Nuez            Poli
# 122  2022   TM  116.96             Suárez               Nuez            Poli
#
#      id_diputado         mes tipo_viaje
# ...

# %%
#eliminacion de campos que se consideran sin relevancia para su analisis
new=df.drop(columns=['tipo','coste','diputado_apellido2'])
new
# Out:
#      anio diputado_apellido1 diputado_nombre  id_diputado         mes  \
# 0    2022             Alemán           Nayra        10040       enero
# 1    2022             Alemán           Nayra        10040     febrero
# 2    2022             Alemán           Nayra        10040       abril
# 3    2022             Alemán           Nayra        10040        mayo
# 4    2022             Alemán           Nayra        10040       junio
# ..    ...                ...             ...          ...         ...
# 118  2022             Suárez            Poli        10069      agosto
# 119  2022             Suárez            Poli        10069  septiembre
# 120  2022             Suárez            Poli        10069     octubre
# 121  2022             Suárez            Poli        10069   noviembre
# 122  2022             Suárez            Poli        10069   diciembre
#
#     tipo_viaje
# 0     maritimo
# 1     maritimo
# 2     maritimo
# 3     maritimo
# 4     maritimo
# ..         ...
# ...

# %%
new = new.rename(columns={'diputado_apellido1':'apellido','diputado_nombre':'nombre'})
new
# Out:
#      anio apellido nombre  id_diputado         mes tipo_viaje
# 0    2022   Alemán  Nayra        10040       enero   maritimo
# 1    2022   Alemán  Nayra        10040     febrero   maritimo
# 2    2022   Alemán  Nayra        10040       abril   maritimo
# 3    2022   Alemán  Nayra        10040        mayo   maritimo
# 4    2022   Alemán  Nayra        10040       junio   maritimo
# ..    ...      ...    ...          ...         ...        ...
# 118  2022   Suárez   Poli        10069      agosto   maritimo
# 119  2022   Suárez   Poli        10069  septiembre   maritimo
# 120  2022   Suárez   Poli        10069     octubre   maritimo
# 121  2022   Suárez   Poli        10069   noviembre   maritimo
# 122  2022   Suárez   Poli        10069   diciembre   maritimo
#
# [123 rows x 6 columns]

# %% [markdown]
# # Conexion y Carga a la BD

# %%
#guardamos y nombramos al archivo que se creo con los datos limpios
new.to_json('archivo_limpio-ViajesDiputados.json', orient='records')
new
# Out:
#      anio apellido nombre  id_diputado         mes tipo_viaje
# 0    2022   Alemán  Nayra        10040       enero   maritimo
# 1    2022   Alemán  Nayra        10040     febrero   maritimo
# 2    2022   Alemán  Nayra        10040       abril   maritimo
# 3    2022   Alemán  Nayra        10040        mayo   maritimo
# 4    2022   Alemán  Nayra        10040       junio   maritimo
# ..    ...      ...    ...          ...         ...        ...
# 118  2022   Suárez   Poli        10069      agosto   maritimo
# 119  2022   Suárez   Poli        10069  septiembre   maritimo
# 120  2022   Suárez   Poli        10069     octubre   maritimo
# 121  2022   Suárez   Poli        10069   noviembre   maritimo
# 122  2022   Suárez   Poli        10069   diciembre   maritimo
#
# [123 rows x 6 columns]

# %%
import MySQLdb
import pymysql
from sqlalchemy import create_engine

#Creamos nuestra base de datos en mysql con el nombreque le querramos poner
nombreDB = input("Ingresa el nombre de la BD: ")
with engine.connect() as con:
    con.execute(f'CREATE DATABASE {nombreDB}')
# Out:
# Ingresa el nombre de la BD: diputados

# %%
# ------------------ DETALLES DE LA CONECCION --------------------------
#En los detalles de la coneccion devemos enviar el los siguientes parametros
""" mysql+pymysql:// USUARIO : CONTRASEÑA @localhost/ Nombre de la bd creada """

#Tomando el siguiente ejemplo para nuestro caso nos quedaria de la siguiente manera
engine = create_engine('mysql+pymysql://root:mysql@localhost/diputados')

# Abrimos la coneccion y visualisamos los datos
new.to_sql('viajes', con=engine, if_exists='replace', index=False)
new
# Out:
#      anio apellido nombre  id_diputado         mes tipo_viaje
# 0    2022   Alemán  Nayra        10040       enero   maritimo
# 1    2022   Alemán  Nayra        10040     febrero   maritimo
# 2    2022   Alemán  Nayra        10040       abril   maritimo
# 3    2022   Alemán  Nayra        10040        mayo   maritimo
# 4    2022   Alemán  Nayra        10040       junio   maritimo
# ..    ...      ...    ...          ...         ...        ...
# 118  2022   Suárez   Poli        10069      agosto   maritimo
# 119  2022   Suárez   Poli        10069  septiembre   maritimo
# 120  2022   Suárez   Poli        10069     octubre   maritimo
# 121  2022   Suárez   Poli        10069   noviembre   maritimo
# 122  2022   Suárez   Poli        10069   diciembre   maritimo
#
# [123 rows x 6 columns]

# %%
#Datos del archivo JSON para saber sus campos
import json

with open('archivo_limpio-ViajesDiputados.json', 'r') as f:
    data = json.load(f)

print(data)
# Out:
# [{'anio': 2022, 'apellido': 'Alemán', 'nombre': 'Nayra', 'id_diputado': 10040, 'mes': 'enero', 'tipo_viaje': 'maritimo'}, {'anio': 2022, 'apellido': 'Alemán', 'nombre': 'Nayra', 'id_diputado': 10040, 'mes': 'febrero', 'tipo_viaje': 'maritimo'}, {'anio': 2022, 'apellido': 'Alemán', 'nombre': 'Nayra', 'id_diputado': 10040, 'mes': 'abril', 'tipo_viaje': 'maritimo'}, {'anio': 2022, 'apellido': 'Alemán', 'nombre': 'Nayra', 'id_diputado': 10040, 'mes': 'mayo', 'tipo_viaje': 'maritimo'}, {'anio': 2022, 'apellido': 'Alemán', 'nombre': 'Nayra', 'id_diputado': 10040, 'mes': 'junio', 'tipo_viaje': 'maritimo'}, {'anio': 2022, 'apellido': 'Alemán', 'nombre': 'Nayra', 'id_diputado': 10040, 'mes': 'julio', 'tipo_viaje': 'maritimo'}, {'anio': 2022, 'apellido': 'Alemán', 'nombre': 'Nayra', 'id_diputado': 10040, 'mes': 'septiembre', 'tipo_viaje': 'maritimo'}, {'anio': 2022, 'apellido': 'Alemán', 'nombre': 'Nayra', 'id_diputado': 10040, 'mes': 'octubre', 'tipo_viaje': 'maritimo'}, {'anio': 2022, 'apell
# ...

# %%
#Visualización de campos que debo transformar para transferir datos a MONGODB
print(data[0].keys())
# Out:
# dict_keys(['anio', 'apellido', 'nombre', 'id_diputado', 'mes', 'tipo_viaje'])

# %% [markdown]
# # Graficos
